# %%
path = '../data/coincap.json'
import pandas as pd
import json

# %%
with open(path, 'r', encoding='utf-8') as f:
    conteudo = json.load(f)

df = pd.DataFrame(conteudo['data'])

df.head()
# Out:
#         id rank symbol     name                       supply  \
# 0  bitcoin    1    BTC  Bitcoin  19999240.000000000000000000
#
#                      maxSupply                      marketCapUsd  \
# 0  21000000.000000000000000000  1345544620126.781005859375000000
#
#                     volumeUsd24Hr                  priceUsd  \
# 0  20024763887.239452362060546875  67279.787638269306626171
#
#      changePercent24Hr           vwap24Hr                  explorer tokens
# 0  -1.5672226620396092  67856.57451644624  https://blockchain.info/     {}

# %%
df.info()
# Out:
# <class 'pandas.DataFrame'>
# RangeIndex: 1 entries, 0 to 0
# Data columns (total 13 columns):
#  #   Column             Non-Null Count  Dtype
# ---  ------             --------------  -----
#  0   id                 1 non-null      str
#  1   rank               1 non-null      str
#  2   symbol             1 non-null      str
#  3   name               1 non-null      str
#  4   supply             1 non-null      str
#  5   maxSupply          1 non-null      str
#  6   marketCapUsd       1 non-null      str
#  7   volumeUsd24Hr      1 non-null      str
#  8   priceUsd           1 non-null      str
#  9   changePercent24Hr  1 non-null      str
#  10  vwap24Hr           1 non-null      str
#  11  explorer           1 non-null      str
#  12  tokens             1 non-null      object
# dtypes: object(1), str(12)
# memory usage: 454.0+ bytes
